# %% [markdown]
# **Maniluplating Strings and Lambda Functions**

# %% [markdown]
# # String Literals

# %% [markdown]
# **Double Quotes**

# %%
spam = 'This is Pam\'s dog.'

# %% [markdown]
# Received an error due to the apostrophe on Pam. Pythin thought the string ended after Pam and the rest (s dog.') is invalid
#
# ---
# To correct, use the double quotes

# %%
spam = "This is Pam's dog."

# %% [markdown]
# **Escape Characters**

# %%
spam = 'Say hi to Pam\'s mother'

# %%
print("Hello there!\nHow are you?\nI'm doing fine")

# %% [markdown]
# **Raw Strings**

# %%
print(r'That is Pam\'s dog.')
# Out:
# That is Pam\'s dog.

# %% [markdown]
# **Multiline Strings with Triple Quotes**
#
# ---
# While you can use the \n escape character to put a newline into a string, it is often easier to use multiline strings

# %%
print('''Dear Alice,

Eve's cat has been arrested for catnapping, cat burglaru, and extortion.

Sincerely,
Bob''')
# Out:
# Dear Alice,
#
# Eve's cat has been arrested for catnapping, cat burglaru, and extortion.
#
# Sincerely,
# Bob

# %% [markdown]
# The above code is the same as the code below.

# %%
print('Dear Alice, \n\nEve\'s cat has been arrested for catnapping, cat burglary, and extortion.\n\nSincerely,\nBob')
# Out:
# Dear Alice,
#
# Eve's cat has been arrested for catnapping, cat burglary, and extortion.
#
# Sincerely,
# Bob

# %% [markdown]
# # Indexing and slicing strings

# %%
spam = "Hello world"
spam[4]
# Out:
# 'o'

# %%
spam[0:5]
# Out:
# 'Hello'

# %% [markdown]
# The substribg you get from spam[0:5] will include everything from spam[0] to spam[4], leaving out the space at index 5

# %% [markdown]
# # The in and not in Operators with Strings

# %% [markdown]
# Can be used with strings just like with list values

# %%
'Hello' in 'Hello World'
# Out:
# True

# %%
'Hello' in 'Hello'
# Out:
# True

# %%
'HELLO' in 'Hello World'

# %%
'' in 'spam'
# Out:
# True

# %%
'cats' not in 'cats and dogs'
# Out:
# False

# %% [markdown]
# # Putting Strings Inside Other Strings

# %%
name = 'Pam'
age = 29
'My name is %s. I am %.1f years old.' % (name, age)
# Out:
# 'My name is Pam. I am 29.0 years old.'

# %%
f'My name is {name}. Next year I will be {age + 1}.'
# Out:
# 'My name is Pam. Next year I will be 30.'

# %% [markdown]
# # String Methods

# %% [markdown]
# **The upper(), lower(), isupper(), and islower() Methods**

# %% [markdown]
# The upper() and lower() methods are helpful if you need to make a case-insenstive comparison
#
# ---
# These methods do not change the string itself but return new string values

# %%
print('How are you?')
feeling = input()
if feeling.lower() == 'great':
  print('I feel great too.')
else:
  print('I hope the rest of your day is good')
# Out:
# How are you?
# I feel great too.

# %% [markdown]
# If you want to change the original string, you have to call upper() or lower() on the string and then assign the new string to the variable where the original was stored

# %%
spam = 'Hello World'
spam = spam.upper()
spam
# Out:
# 'HELLO WORLD'

# %% [markdown]
# The isupper() and islower() methods will return a Boolean True value if the string has at least one letter and all the letters are uppercase or lowercase. Otherwise it returns a False

# %%
spam = 'Hello, world!'
spam.islower()
# Out:
# 'hello, world!'

# %%
spam.isupper()
# Out:
# False

# %%
'HELLO'.isupper()
# Out:
# True

# %% [markdown]
# The isX() Methods
# ---
# Helpful when you need to validate user input

# %% [markdown]
# isdecimal() --> Returns *True* if the string consists only of numeric characters and is not blank

# %%
while True:
  print('Enter your age: ')
  age = input()
  if age.isdecimal():
    break
  print('Please enter a number for your age')
# Out:
# Enter your age:
# Please enter a number for your age
# Enter your age:
# Please enter a number for your age
# Enter your age:

# %% [markdown]
# isalnum() --> Returns *True* if the string consists only of letters and numbers

# %%
while True:
  print('Select a new password (letters and numbers only): ')
  password = input()
  if password.isalnum():
    break
  print('Passwords can only have letters and numbers')
# Out:
# Select a new password (letters and numbers only):

# %% [markdown]
# startswith() and *endswith()* --> returns True if the string value they are called on begins or ends with the string paased to the method. Otherwise they return *False*
#
# ---
# Useful aletrnatives to the == equals operator if you need to check only whether the first or last part of the string is equal to another string.

# %%
'Hello, world. My name is Pam'.startswith('Hello')
# Out:
# False

# %%
'Hello, world. My name is Pam'.endswith('Pam')
# Out:
# True

# %% [markdown]
# The *join()* and *split()* Methods
#
# ---
# *join()* method is ueful when you have a list of strings that need to be joined together into a single string value. It is called on a string value and is passed a list value.
#
# ---
# *split()* method does the opposite: it's called on a string value and returns a list of strings. By default, string is split wherever whitesapce characters such as space, tab, or newline characters are found.

# %%
' '.join(['My', 'name', 'is', 'Pam'])
# Out:
# 'My name is Pam'

# %%
'XXX'.join(['My', 'name', 'is', 'Pam'])
# Out:
# 'MyXXXnameXXXisXXXPam'

# %%
'My name is Pam'.split()
# Out:
# ['My', 'name', 'is', 'Pam']

# %% [markdown]
# You can pass a delimiter string to the *split()* method to specify a different string to split on.

# %%
'My name is Pam'.split('a')
# Out:
# ['My n', 'me is P', 'm']

# %% [markdown]
# A common use of *split()* is to split a multiline string along the new line character. This lets us split the miltiline string stored in *spam* along the newlines and return a list in which each item correspons to one line of the string.

# %%
spam = '''Dear Alice,
Eve's cat has been arrested for catnapping,
cat burglary,
and extortion.
Sincerely,
Bob'''

one=spam.split('\n')
one[1]
# Out:
# "Eve's cat has been arrested for catnapping,"

# %% [markdown]
# Justifying text with rjust(), ljust(), and center() Methods

# %%
'Hello'.rjust(20)
# Out:
# '               Hello'

# %%
'Hello World'.rjust(20)
# Out:
# '         Hello World'

# %%
'Hello'.ljust(20)
# Out:
# 'Hello               '

# %%
for i in range(5):
    print('Hello'.rjust(6,str(i)))
# Out:
# 0Hello
# 1Hello
# 2Hello
# 3Hello
# 4Hello

# %%
'Hello'.center(20,'=')
# Out:
# '=======Hello========'

# %% [markdown]
# Removing Whitespace with strip(), rstrip(), and lstrip() Methods

# %%
spam = '   Hello World   '
spam.strip()
# Out:
# 'Hello World'

# %%
spam = '   Hello World   '
spam.lstrip()
# Out:
# 'Hello World   '

# %%
spam = '   Hello World   '
spam.rstrip()
# Out:
# '   Hello World'

# %%
spam = 'SpamSpamBaconSpamEggsSpamSpam'
spam.strip('ampS')            # order does not matter
# Out:
# 'BaconSpamEggs'

# %% [markdown]
# format() Method

# %%
name = 'Bob'
age = 20
print("{0} has {1}! {0}".format(name,age))
# Out:
# Bob has 20! Bob

# %%
print("{} has {}!".format(name,age))
# Out:
# Bob has 20!

# %%
print("{1} has {0}!".format(name,age))
# Out:
# 20 has Bob!

# %% [markdown]
# # LAMBDA Functions (Not in textbook)

# %%
def add(x, y):
  return x + y

print(add(5, 3))
# Out:
# 8

# %%
add = lambda x,z, y: x**z+y
print(add(5, 3,2))
# Out:
# 127

# %%
print((lambda x, y:x + y)(5, 3))
# Out:
# 8

# %%
(lambda x, y:x + y)(5, 3)
# Out:
# 8

# %% [markdown]
# Anonymous function inside another function

# %%
def makeAdder(n):         # A function that accepts one arg(n), and that arg will be added with unknown number (x)
  return lambda x:x + n         

plus3 = makeAdder(3)    # make a function that always adds the number you send in with 3
plus5 = makeAdder(5)    # # make a function that always adds the number you send in with 5

print(plus3(4))
print(plus5(4))
