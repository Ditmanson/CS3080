# %% [markdown]
# Tuples
#
# ---
# Once a tuple is defined you cannot change what is stored in it. Tuples are usually used for menu tiems that would not need to be chaged.
#
# ---
# Code below reates a variable name called "fruit_tuple" which stores four pieces of fruit within it. The round brackets define this group as a tuple and therefore the contents of this collection of data cannot be altered while the program is running

# %%
fruit_tuple = ("apple", "banana","strawberry", "orange")

# %% [markdown]
# Assignment for Tuples
#
# ---
# Create a list of six school subjects. Ask the user which of these subjects they don't like. Delete the subject they have chosen from the list before you display the list again.

# %% [markdown]
# Random
# ---
# Python can generate random values. There are two types of random value that we will look at:
#
#
# *   Random numbers within a specified range
# *   A random choice from a range of items that are input

# %% [markdown]
# Assignment for Random
#
# ---
# (1) Make a math quiz that asks five questions by randomly generating two whole numbers(between 0 and 50) to make the question (e.g. [num1] + [num2]). Ask the user to enter the answer. If they get it right add a point to their score. At the end of the quiz, tell them how many they got correct out of five.

# %% [markdown]
# (2) Randomly choose either heads or tails ('h' or 't'). Ask the user to make their choice. If their choice is the same as the randomly selected value, display the message "you win", otherwise display "Bad luck". At the end, tell the user if the computer selected heads or tails.

# %% [markdown]
# Lists
#
# ---
# The content of a list can be changed while the program is running. Data in a list does not have to be of the same data type.

# %% [markdown]
# Assignment for Lists
#
# ---
# Create a list containing the names of four of your favorite foods and display them on separate lines. Ask the user to enter another favorite food and a position they want it inserted into the list. Display the list again, showing all five favorite foods in their new positions.

# %% [markdown]
# Loops
#
#
# *   If statement
#
# > Allows program to make a decision and change the route that is taken through the program
#
# *   For Loop
#
# > Allows python to keep repeating code a set number of times
#
# *   While Loop
#
# > Allows code to be repeated an unknown number of times as long as a condition is being met.

# %% [markdown]
# **Assignment for If statement**
#
# Display the following message:
#
# 1.   Square
# 2.   Triangle
#
# Enter a number:
#
# ---
# If the user enters 1, then it should ask them for the length of one of its sides and siplay the area. If they select 2, it should ask for the base and height of the triangle and displa the area. If they type in anything else, it should give them a suitable error message.

# %% [markdown]
# **Assignment for while loop**
# Set the totl to 0 to start. While the total is 50 or less, ask the user to input a number. Add that number to the total and print the message "The total is... [total]". Stop the loop when the total is *over 50*

# %% [markdown]
# Turtle Graphics
#
#
# ---
# It is possible to draw using a turtle in Python. By typing in commands and using loops, you can create intricate patterns.
#
# Here is how it works
#
#
# ---
# When you use turtle, it will open a Window display. So, ou can not import turtle in Google Colab as it is on the internet and cannot open a new window on your screen. Instead, go to your command line and type the following commands.
#
# A trutle will travel along a path that you define, leaving a pen mark behind it. As you control the turtle, the pattern that is left is revealed. To draw the pentagon shown below you would type in the following code.
#
#
# <div><center>
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20201007234311/polly-300x259.png" width="200"/>
# </div>

# %% [markdown]
# A turtle will travel along a path that you define, leaving a pen mark behind it. As you control the turtle, the pattern that is left is revealed. To draw the pentagon shown below, type in the following cod at your command line. Don't forget to start python.
#
#
# <div><center>
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20201007234311/polly-300x259.png" width="200"/>
# </div>

# %%
import turtle
s = turtle.getscreen()
t = turtle.Turtle()

for i in range(0,5):
  t.forward(100)
  t.right(90)

# %% [markdown]
# You can clear your window display using the t.clear() command
#
# ---
# Let's create a really cool pattern. Type the following code after you clear your window display.

# %%
for i in range(0,10):
  t.right(36)
  for i in range(0,5):
    t.forward(100)
    t.right(72)

# %% [markdown]
# **Assignment for Turtle Graphics**
#
# ---
# In the cell below, type the code you used to draw a square.
